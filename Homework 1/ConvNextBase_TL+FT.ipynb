# %% [markdown]
# # ConvNeXtBase: TL and FT

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/Copia Challenge 1
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/Copia Challenge 1

# %% [markdown]
# ## Imports

# %%
# Fix randomness and hide warnings
seed = 46

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import seaborn as sns
from tensorflow.keras.applications.efficientnet import preprocess_input

# %% [markdown]
# ## Loading the data

# %%
# Load the data
loaded = np.load('clean_public_data.npz', allow_pickle=True)
data = loaded['data']
labels = loaded['labels']

# %%
# Normalize data to the range [0, 1]
data = (data / 255).astype('float32')

# Convert labels to categorical format using one-hot encoding
labels=pd.get_dummies(labels)

# %% [markdown]
# ## Splitting the data

# %%
# Split data into training and validation sets, maintaining class distribution
data_train_val, data_test, labels_train_val, labels_test = train_test_split(data, labels, random_state=seed, test_size=0.1, stratify=labels)

# Split data into training and test sets, maintaining class distribution
data_train, data_val, labels_train, labels_val = train_test_split(data_train_val, labels_train_val, random_state=seed, test_size=0.1, stratify=labels_train_val)

# Print the shapes of the resulting datasets
print("Training Data Shape:", data_train.shape)
print("Training Label Shape:", labels_train.shape)
print("Validation Data Shape:", data_val.shape)
print("Validation Label Shape:", labels_val.shape)
print("Test Data Shape:", data_val.shape)
print("Test Label Shape:", labels_val.shape)
# Out:
# Training Data Shape: (4052, 96, 96, 3)
# Training Label Shape: (4052, 2)
# Validation Data Shape: (451, 96, 96, 3)
# Validation Label Shape: (451, 2)
# Test Data Shape: (451, 96, 96, 3)
# Test Label Shape: (451, 2)

# %% [markdown]
# # Transfer Learning ConvNeXtBase

# %%
# Define key model parameters
input_shape = data_train.shape[1:]    # Input shape for the model
output_shape = labels_train.shape[1]  # Output shape for the model
batch_size = 32                       # Batch size for training
epochs = 180

# %%
# Define ConvNeXtBase network
supernet = tfk.applications.ConvNeXtBase(
      include_top=False,
      weights="imagenet",
      input_shape=(96,96,3),
      pooling='avg',
      classifier_activation='softmax'
)

supernet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 [==============================] - 2s 0us/step
# Model: "convnext_base"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 3)]          0         []
#
#  convnext_base_prestem_norm  (None, 96, 96, 3)            0         ['input_1[0][0]']
#  alization (Normalization)
#
#  convnext_base_stem (Sequen  (None, 24, 24, 128)          6528      ['convnext_base_prestem_normal
#  tial)                                                              ization[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          6400      ['convnext_base_stem[0][0]']
#  k_0_depthwise_conv (Conv2D
#  )
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          256       ['convnext_base_stage_0_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 512)          66048     ['convnext_base_stage_0_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 512)          0         ['convnext_base_stage_0_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          65664     ['convnext_base_stage_0_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          128       ['convnext_base_stage_0_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          0         ['convnext_base_stage_0_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 24, 24, 128)          0         ['convnext_base_stem[0][0]',
#  Lambda)                                                             'convnext_base_stage_0_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          6400      ['tf.__operators__.add[0][0]']
#  k_1_depthwise_conv (Conv2D
#  )
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          256       ['convnext_base_stage_0_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 512)          66048     ['convnext_base_stage_0_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 512)          0         ['convnext_base_stage_0_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          65664     ['convnext_base_stage_0_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          128       ['convnext_base_stage_0_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          0         ['convnext_base_stage_0_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 24, 24, 128)          0         ['tf.__operators__.add[0][0]',
#  OpLambda)                                                           'convnext_base_stage_0_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          6400      ['tf.__operators__.add_1[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          256       ['convnext_base_stage_0_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 512)          66048     ['convnext_base_stage_0_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 512)          0         ['convnext_base_stage_0_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          65664     ['convnext_base_stage_0_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          128       ['convnext_base_stage_0_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_0_bloc  (None, 24, 24, 128)          0         ['convnext_base_stage_0_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_2 (TF  (None, 24, 24, 128)          0         ['tf.__operators__.add_1[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_base_stage_0_block_
#                                                                     2_identity[0][0]']
#
#  convnext_base_downsampling  (None, 12, 12, 256)          131584    ['tf.__operators__.add_2[0][0]
#  _block_0 (Sequential)                                              ']
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          12800     ['convnext_base_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_0[0][0]']
#  )
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          512       ['convnext_base_stage_1_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 1024)         263168    ['convnext_base_stage_1_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 1024)         0         ['convnext_base_stage_1_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          262400    ['convnext_base_stage_1_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          256       ['convnext_base_stage_1_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          0         ['convnext_base_stage_1_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 12, 12, 256)          0         ['convnext_base_downsampling_b
#  OpLambda)                                                          lock_0[0][0]',
#                                                                      'convnext_base_stage_1_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          12800     ['tf.__operators__.add_3[0][0]
#  k_1_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          512       ['convnext_base_stage_1_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 1024)         263168    ['convnext_base_stage_1_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 1024)         0         ['convnext_base_stage_1_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          262400    ['convnext_base_stage_1_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          256       ['convnext_base_stage_1_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          0         ['convnext_base_stage_1_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_4 (TF  (None, 12, 12, 256)          0         ['tf.__operators__.add_3[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_base_stage_1_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          12800     ['tf.__operators__.add_4[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          512       ['convnext_base_stage_1_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 1024)         263168    ['convnext_base_stage_1_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 1024)         0         ['convnext_base_stage_1_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          262400    ['convnext_base_stage_1_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          256       ['convnext_base_stage_1_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_1_bloc  (None, 12, 12, 256)          0         ['convnext_base_stage_1_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 12, 12, 256)          0         ['tf.__operators__.add_4[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_base_stage_1_block_
#                                                                     2_identity[0][0]']
#
#  convnext_base_downsampling  (None, 6, 6, 512)            525312    ['tf.__operators__.add_5[0][0]
#  _block_1 (Sequential)                                              ']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            25600     ['convnext_base_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_1[0][0]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1024      ['convnext_base_stage_2_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           1050624   ['convnext_base_stage_2_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           0         ['convnext_base_stage_2_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1049088   ['convnext_base_stage_2_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            512       ['convnext_base_stage_2_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            0         ['convnext_base_stage_2_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_6 (TF  (None, 6, 6, 512)            0         ['convnext_base_downsampling_b
#  OpLambda)                                                          lock_1[0][0]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            25600     ['tf.__operators__.add_6[0][0]
#  k_1_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1024      ['convnext_base_stage_2_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           1050624   ['convnext_base_stage_2_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           0         ['convnext_base_stage_2_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1049088   ['convnext_base_stage_2_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            512       ['convnext_base_stage_2_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            0         ['convnext_base_stage_2_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 6, 6, 512)            0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_base_stage_2_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            25600     ['tf.__operators__.add_7[0][0]
#  k_2_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1024      ['convnext_base_stage_2_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           1050624   ['convnext_base_stage_2_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           0         ['convnext_base_stage_2_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1049088   ['convnext_base_stage_2_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            512       ['convnext_base_stage_2_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            0         ['convnext_base_stage_2_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_8 (TF  (None, 6, 6, 512)            0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_base_stage_2_block_
#                                                                     2_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            25600     ['tf.__operators__.add_8[0][0]
#  k_3_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1024      ['convnext_base_stage_2_block_
#  k_3_layernorm (LayerNormal                                         3_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           1050624   ['convnext_base_stage_2_block_
#  k_3_pointwise_conv_1 (Dens                                         3_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           0         ['convnext_base_stage_2_block_
#  k_3_gelu (Activation)                                              3_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1049088   ['convnext_base_stage_2_block_
#  k_3_pointwise_conv_2 (Dens                                         3_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            512       ['convnext_base_stage_2_block_
#  k_3_layer_scale (LayerScal                                         3_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            0         ['convnext_base_stage_2_block_
#  k_3_identity (Activation)                                          3_layer_scale[0][0]']
#
#  tf.__operators__.add_9 (TF  (None, 6, 6, 512)            0         ['tf.__operators__.add_8[0][0]
#  OpLambda)                                                          ',
#                                                                      'convnext_base_stage_2_block_
#                                                                     3_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            25600     ['tf.__operators__.add_9[0][0]
#  k_4_depthwise_conv (Conv2D                                         ']
#  )
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1024      ['convnext_base_stage_2_block_
#  k_4_layernorm (LayerNormal                                         4_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           1050624   ['convnext_base_stage_2_block_
#  k_4_pointwise_conv_1 (Dens                                         4_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           0         ['convnext_base_stage_2_block_
#  k_4_gelu (Activation)                                              4_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1049088   ['convnext_base_stage_2_block_
#  k_4_pointwise_conv_2 (Dens                                         4_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            512       ['convnext_base_stage_2_block_
#  k_4_layer_scale (LayerScal                                         4_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            0         ['convnext_base_stage_2_block_
#  k_4_identity (Activation)                                          4_layer_scale[0][0]']
#
#  tf.__operators__.add_10 (T  (None, 6, 6, 512)            0         ['tf.__operators__.add_9[0][0]
#  FOpLambda)                                                         ',
#                                                                      'convnext_base_stage_2_block_
#                                                                     4_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            25600     ['tf.__operators__.add_10[0][0
#  k_5_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1024      ['convnext_base_stage_2_block_
#  k_5_layernorm (LayerNormal                                         5_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           1050624   ['convnext_base_stage_2_block_
#  k_5_pointwise_conv_1 (Dens                                         5_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           0         ['convnext_base_stage_2_block_
#  k_5_gelu (Activation)                                              5_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1049088   ['convnext_base_stage_2_block_
#  k_5_pointwise_conv_2 (Dens                                         5_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            512       ['convnext_base_stage_2_block_
#  k_5_layer_scale (LayerScal                                         5_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            0         ['convnext_base_stage_2_block_
#  k_5_identity (Activation)                                          5_layer_scale[0][0]']
#
#  tf.__operators__.add_11 (T  (None, 6, 6, 512)            0         ['tf.__operators__.add_10[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     5_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            25600     ['tf.__operators__.add_11[0][0
#  k_6_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1024      ['convnext_base_stage_2_block_
#  k_6_layernorm (LayerNormal                                         6_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           1050624   ['convnext_base_stage_2_block_
#  k_6_pointwise_conv_1 (Dens                                         6_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           0         ['convnext_base_stage_2_block_
#  k_6_gelu (Activation)                                              6_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1049088   ['convnext_base_stage_2_block_
#  k_6_pointwise_conv_2 (Dens                                         6_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            512       ['convnext_base_stage_2_block_
#  k_6_layer_scale (LayerScal                                         6_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            0         ['convnext_base_stage_2_block_
#  k_6_identity (Activation)                                          6_layer_scale[0][0]']
#
#  tf.__operators__.add_12 (T  (None, 6, 6, 512)            0         ['tf.__operators__.add_11[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     6_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            25600     ['tf.__operators__.add_12[0][0
#  k_7_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1024      ['convnext_base_stage_2_block_
#  k_7_layernorm (LayerNormal                                         7_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           1050624   ['convnext_base_stage_2_block_
#  k_7_pointwise_conv_1 (Dens                                         7_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           0         ['convnext_base_stage_2_block_
#  k_7_gelu (Activation)                                              7_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1049088   ['convnext_base_stage_2_block_
#  k_7_pointwise_conv_2 (Dens                                         7_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            512       ['convnext_base_stage_2_block_
#  k_7_layer_scale (LayerScal                                         7_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            0         ['convnext_base_stage_2_block_
#  k_7_identity (Activation)                                          7_layer_scale[0][0]']
#
#  tf.__operators__.add_13 (T  (None, 6, 6, 512)            0         ['tf.__operators__.add_12[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     7_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            25600     ['tf.__operators__.add_13[0][0
#  k_8_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1024      ['convnext_base_stage_2_block_
#  k_8_layernorm (LayerNormal                                         8_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           1050624   ['convnext_base_stage_2_block_
#  k_8_pointwise_conv_1 (Dens                                         8_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           0         ['convnext_base_stage_2_block_
#  k_8_gelu (Activation)                                              8_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1049088   ['convnext_base_stage_2_block_
#  k_8_pointwise_conv_2 (Dens                                         8_gelu[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            512       ['convnext_base_stage_2_block_
#  k_8_layer_scale (LayerScal                                         8_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            0         ['convnext_base_stage_2_block_
#  k_8_identity (Activation)                                          8_layer_scale[0][0]']
#
#  tf.__operators__.add_14 (T  (None, 6, 6, 512)            0         ['tf.__operators__.add_13[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     8_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            25600     ['tf.__operators__.add_14[0][0
#  k_9_depthwise_conv (Conv2D                                         ]']
# ...
#  lization)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           1050624   ['convnext_base_stage_2_block_
#  k_25_pointwise_conv_1 (Den                                         25_layernorm[0][0]']
#  se)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           0         ['convnext_base_stage_2_block_
#  k_25_gelu (Activation)                                             25_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1049088   ['convnext_base_stage_2_block_
#  k_25_pointwise_conv_2 (Den                                         25_gelu[0][0]']
#  se)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            512       ['convnext_base_stage_2_block_
#  k_25_layer_scale (LayerSca                                         25_pointwise_conv_2[0][0]']
#  le)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            0         ['convnext_base_stage_2_block_
#  k_25_identity (Activation)                                         25_layer_scale[0][0]']
#
#  tf.__operators__.add_31 (T  (None, 6, 6, 512)            0         ['tf.__operators__.add_30[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     25_identity[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            25600     ['tf.__operators__.add_31[0][0
#  k_26_depthwise_conv (Conv2                                         ]']
#  D)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1024      ['convnext_base_stage_2_block_
#  k_26_layernorm (LayerNorma                                         26_depthwise_conv[0][0]']
#  lization)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           1050624   ['convnext_base_stage_2_block_
#  k_26_pointwise_conv_1 (Den                                         26_layernorm[0][0]']
#  se)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 2048)           0         ['convnext_base_stage_2_block_
#  k_26_gelu (Activation)                                             26_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            1049088   ['convnext_base_stage_2_block_
#  k_26_pointwise_conv_2 (Den                                         26_gelu[0][0]']
#  se)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            512       ['convnext_base_stage_2_block_
#  k_26_layer_scale (LayerSca                                         26_pointwise_conv_2[0][0]']
#  le)
#
#  convnext_base_stage_2_bloc  (None, 6, 6, 512)            0         ['convnext_base_stage_2_block_
#  k_26_identity (Activation)                                         26_layer_scale[0][0]']
#
#  tf.__operators__.add_32 (T  (None, 6, 6, 512)            0         ['tf.__operators__.add_31[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_2_block_
#                                                                     26_identity[0][0]']
#
#  convnext_base_downsampling  (None, 3, 3, 1024)           2099200   ['tf.__operators__.add_32[0][0
#  _block_2 (Sequential)                                              ]']
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           51200     ['convnext_base_downsampling_b
#  k_0_depthwise_conv (Conv2D                                         lock_2[0][0]']
#  )
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           2048      ['convnext_base_stage_3_block_
#  k_0_layernorm (LayerNormal                                         0_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 4096)           4198400   ['convnext_base_stage_3_block_
#  k_0_pointwise_conv_1 (Dens                                         0_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 4096)           0         ['convnext_base_stage_3_block_
#  k_0_gelu (Activation)                                              0_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           4195328   ['convnext_base_stage_3_block_
#  k_0_pointwise_conv_2 (Dens                                         0_gelu[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           1024      ['convnext_base_stage_3_block_
#  k_0_layer_scale (LayerScal                                         0_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           0         ['convnext_base_stage_3_block_
#  k_0_identity (Activation)                                          0_layer_scale[0][0]']
#
#  tf.__operators__.add_33 (T  (None, 3, 3, 1024)           0         ['convnext_base_downsampling_b
#  FOpLambda)                                                         lock_2[0][0]',
#                                                                      'convnext_base_stage_3_block_
#                                                                     0_identity[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           51200     ['tf.__operators__.add_33[0][0
#  k_1_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           2048      ['convnext_base_stage_3_block_
#  k_1_layernorm (LayerNormal                                         1_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 4096)           4198400   ['convnext_base_stage_3_block_
#  k_1_pointwise_conv_1 (Dens                                         1_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 4096)           0         ['convnext_base_stage_3_block_
#  k_1_gelu (Activation)                                              1_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           4195328   ['convnext_base_stage_3_block_
#  k_1_pointwise_conv_2 (Dens                                         1_gelu[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           1024      ['convnext_base_stage_3_block_
#  k_1_layer_scale (LayerScal                                         1_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           0         ['convnext_base_stage_3_block_
#  k_1_identity (Activation)                                          1_layer_scale[0][0]']
#
#  tf.__operators__.add_34 (T  (None, 3, 3, 1024)           0         ['tf.__operators__.add_33[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_3_block_
#                                                                     1_identity[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           51200     ['tf.__operators__.add_34[0][0
#  k_2_depthwise_conv (Conv2D                                         ]']
#  )
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           2048      ['convnext_base_stage_3_block_
#  k_2_layernorm (LayerNormal                                         2_depthwise_conv[0][0]']
#  ization)
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 4096)           4198400   ['convnext_base_stage_3_block_
#  k_2_pointwise_conv_1 (Dens                                         2_layernorm[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 4096)           0         ['convnext_base_stage_3_block_
#  k_2_gelu (Activation)                                              2_pointwise_conv_1[0][0]']
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           4195328   ['convnext_base_stage_3_block_
#  k_2_pointwise_conv_2 (Dens                                         2_gelu[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           1024      ['convnext_base_stage_3_block_
#  k_2_layer_scale (LayerScal                                         2_pointwise_conv_2[0][0]']
#  e)
#
#  convnext_base_stage_3_bloc  (None, 3, 3, 1024)           0         ['convnext_base_stage_3_block_
#  k_2_identity (Activation)                                          2_layer_scale[0][0]']
#
#  tf.__operators__.add_35 (T  (None, 3, 3, 1024)           0         ['tf.__operators__.add_34[0][0
#  FOpLambda)                                                         ]',
#                                                                      'convnext_base_stage_3_block_
#                                                                     2_identity[0][0]']
#
#  global_average_pooling2d (  (None, 1024)                 0         ['tf.__operators__.add_35[0][0
#  GlobalAveragePooling2D)                                            ]']
#
#  layer_normalization (Layer  (None, 1024)                 2048      ['global_average_pooling2d[0][
#  Normalization)                                                     0]']
#
# ==================================================================================================
# Total params: 87566464 (334.04 MB)
# Trainable params: 87566464 (334.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tfk.utils.plot_model(supernet)
supernet.trainable = False

# %%
def build_Net(input_shape, output_shape, seed=seed):

  tf.random.set_seed(seed)

  preprocessing = tf.keras.Sequential([
      tfkl.RandomFlip(mode='horizontal'),
      tfkl.RandomFlip(mode='vertical'),
      tfkl.RandomRotation(factor=0.15)

  ], name='preprocessing')

  inputs = tfk.Input(shape=(96,96,3))

  x=preprocessing(inputs)

  x = supernet(x)
  #x = tfkl.Flatten(name='Flattening')(x)
  x = tfkl.Dropout(0.3, seed=seed)(x)
  #x = tfkl.Dense(256, activation='relu')(x)

  output_layer = tfkl.Dense(units=2, activation='softmax', name='Output')(x)

  # Connect input and output through the Model class
  model = tfk.Model(inputs=inputs, outputs=output_layer, name='convnext_base')

  # Compile the model
  model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['accuracy'])

  # Return the model
  return model

# %%
model = build_Net(input_shape, output_shape)

# %%
# Define early stopping callback
early_stopping = tfk.callbacks.EarlyStopping(monitor='val_accuracy', patience=20, mode='max', restore_best_weights=True)

# Train the model and save its history
history = model.fit(
    x=preprocess_input(data_train*255),
    y=labels_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(preprocess_input(data_val*255), labels_val),
    callbacks=[early_stopping]
).history
# Out:
# Epoch 1/180
# 127/127 [==============================] - 65s 263ms/step - loss: 0.6313 - accuracy: 0.6955 - val_loss: 0.4279 - val_accuracy: 0.8004
# Epoch 2/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.4882 - accuracy: 0.7655 - val_loss: 0.4586 - val_accuracy: 0.7849
# Epoch 3/180
# 127/127 [==============================] - 18s 143ms/step - loss: 0.4600 - accuracy: 0.7994 - val_loss: 0.4507 - val_accuracy: 0.7827
# Epoch 4/180
# 127/127 [==============================] - 21s 165ms/step - loss: 0.4429 - accuracy: 0.7991 - val_loss: 0.3867 - val_accuracy: 0.8359
# Epoch 5/180
# 127/127 [==============================] - 23s 185ms/step - loss: 0.4115 - accuracy: 0.8164 - val_loss: 0.4397 - val_accuracy: 0.7871
# Epoch 6/180
# 127/127 [==============================] - 20s 157ms/step - loss: 0.4263 - accuracy: 0.8152 - val_loss: 0.3998 - val_accuracy: 0.8271
# Epoch 7/180
# 127/127 [==============================] - 21s 164ms/step - loss: 0.4124 - accuracy: 0.8142 - val_loss: 0.3666 - val_accuracy: 0.8381
# Epoch 8/180
# 127/127 [==============================] - 18s 143ms/step - loss: 0.3974 - accuracy: 0.8248 - val_loss: 0.3811 - val_accuracy: 0.8271
# Epoch 9/180
# 127/127 [==============================] - 18s 142ms/step - loss: 0.4124 - accuracy: 0.8142 - val_loss: 0.3927 - val_accuracy: 0.8137
# Epoch 10/180
# 127/127 [==============================] - 20s 155ms/step - loss: 0.4096 - accuracy: 0.8161 - val_loss: 0.3506 - val_accuracy: 0.8426
# Epoch 11/180
# 127/127 [==============================] - 19s 153ms/step - loss: 0.4024 - accuracy: 0.8196 - val_loss: 0.3668 - val_accuracy: 0.8226
# Epoch 12/180
# 127/127 [==============================] - 19s 151ms/step - loss: 0.3844 - accuracy: 0.8265 - val_loss: 0.3429 - val_accuracy: 0.8559
# Epoch 13/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.3939 - accuracy: 0.8268 - val_loss: 0.4195 - val_accuracy: 0.8071
# Epoch 14/180
# 127/127 [==============================] - 18s 142ms/step - loss: 0.4006 - accuracy: 0.8258 - val_loss: 0.3569 - val_accuracy: 0.8470
# Epoch 15/180
# 127/127 [==============================] - 18s 144ms/step - loss: 0.4085 - accuracy: 0.8169 - val_loss: 0.3500 - val_accuracy: 0.8470
# Epoch 16/180
# 127/127 [==============================] - 19s 148ms/step - loss: 0.4014 - accuracy: 0.8233 - val_loss: 0.3744 - val_accuracy: 0.8404
# Epoch 17/180
# 127/127 [==============================] - 19s 150ms/step - loss: 0.4022 - accuracy: 0.8253 - val_loss: 0.3909 - val_accuracy: 0.8204
# Epoch 18/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.4070 - accuracy: 0.8260 - val_loss: 0.3621 - val_accuracy: 0.8492
# Epoch 19/180
# 127/127 [==============================] - 18s 142ms/step - loss: 0.3840 - accuracy: 0.8339 - val_loss: 0.3598 - val_accuracy: 0.8337
# Epoch 20/180
# 127/127 [==============================] - 18s 143ms/step - loss: 0.3953 - accuracy: 0.8309 - val_loss: 0.4077 - val_accuracy: 0.8160
# Epoch 21/180
# 127/127 [==============================] - 18s 143ms/step - loss: 0.3993 - accuracy: 0.8179 - val_loss: 0.3529 - val_accuracy: 0.8426
# Epoch 22/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.3851 - accuracy: 0.8253 - val_loss: 0.3530 - val_accuracy: 0.8404
# Epoch 23/180
# 127/127 [==============================] - 19s 150ms/step - loss: 0.3773 - accuracy: 0.8354 - val_loss: 0.3828 - val_accuracy: 0.8315
# Epoch 24/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.3988 - accuracy: 0.8245 - val_loss: 0.3674 - val_accuracy: 0.8448
# Epoch 25/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.3809 - accuracy: 0.8359 - val_loss: 0.4389 - val_accuracy: 0.8093
# Epoch 26/180
# 127/127 [==============================] - 18s 142ms/step - loss: 0.3950 - accuracy: 0.8253 - val_loss: 0.3542 - val_accuracy: 0.8492
# Epoch 27/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.3926 - accuracy: 0.8253 - val_loss: 0.3976 - val_accuracy: 0.8337
# Epoch 28/180
# 127/127 [==============================] - 18s 144ms/step - loss: 0.3900 - accuracy: 0.8297 - val_loss: 0.3661 - val_accuracy: 0.8160
# Epoch 29/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.4042 - accuracy: 0.8211 - val_loss: 0.3929 - val_accuracy: 0.8204
# Epoch 30/180
# 127/127 [==============================] - 18s 143ms/step - loss: 0.3997 - accuracy: 0.8268 - val_loss: 0.3656 - val_accuracy: 0.8337
# Epoch 31/180
# 127/127 [==============================] - 19s 151ms/step - loss: 0.3854 - accuracy: 0.8297 - val_loss: 0.3453 - val_accuracy: 0.8625
# Epoch 32/180
# 127/127 [==============================] - 19s 151ms/step - loss: 0.3860 - accuracy: 0.8307 - val_loss: 0.3344 - val_accuracy: 0.8670
# Epoch 33/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.3919 - accuracy: 0.8228 - val_loss: 0.3948 - val_accuracy: 0.8271
# Epoch 34/180
# 127/127 [==============================] - 19s 150ms/step - loss: 0.4096 - accuracy: 0.8181 - val_loss: 0.3436 - val_accuracy: 0.8603
# Epoch 35/180
# 127/127 [==============================] - 19s 148ms/step - loss: 0.3978 - accuracy: 0.8211 - val_loss: 0.3752 - val_accuracy: 0.8293
# Epoch 36/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.4006 - accuracy: 0.8226 - val_loss: 0.3482 - val_accuracy: 0.8537
# Epoch 37/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.4024 - accuracy: 0.8240 - val_loss: 0.3590 - val_accuracy: 0.8426
# Epoch 38/180
# 127/127 [==============================] - 18s 145ms/step - loss: 0.4009 - accuracy: 0.8216 - val_loss: 0.3715 - val_accuracy: 0.8359
# Epoch 39/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.4088 - accuracy: 0.8191 - val_loss: 0.3657 - val_accuracy: 0.8404
# Epoch 40/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.3987 - accuracy: 0.8171 - val_loss: 0.3931 - val_accuracy: 0.8315
# Epoch 41/180
# 127/127 [==============================] - 18s 142ms/step - loss: 0.4113 - accuracy: 0.8186 - val_loss: 0.3600 - val_accuracy: 0.8315
# Epoch 42/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.3935 - accuracy: 0.8184 - val_loss: 0.4111 - val_accuracy: 0.8093
# Epoch 43/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.3949 - accuracy: 0.8272 - val_loss: 0.3582 - val_accuracy: 0.8404
# Epoch 44/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.3841 - accuracy: 0.8260 - val_loss: 0.3325 - val_accuracy: 0.8581
# Epoch 45/180
# 127/127 [==============================] - 19s 148ms/step - loss: 0.3882 - accuracy: 0.8238 - val_loss: 0.3395 - val_accuracy: 0.8581
# Epoch 46/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.3905 - accuracy: 0.8305 - val_loss: 0.3289 - val_accuracy: 0.8581
# Epoch 47/180
# 127/127 [==============================] - 19s 148ms/step - loss: 0.4072 - accuracy: 0.8174 - val_loss: 0.4429 - val_accuracy: 0.8004
# Epoch 48/180
# 127/127 [==============================] - 19s 150ms/step - loss: 0.4034 - accuracy: 0.8223 - val_loss: 0.3648 - val_accuracy: 0.8293
# Epoch 49/180
# 127/127 [==============================] - 18s 144ms/step - loss: 0.4009 - accuracy: 0.8171 - val_loss: 0.3293 - val_accuracy: 0.8647
# Epoch 50/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.3956 - accuracy: 0.8193 - val_loss: 0.4034 - val_accuracy: 0.8182
# Epoch 51/180
# 127/127 [==============================] - 19s 149ms/step - loss: 0.4064 - accuracy: 0.8208 - val_loss: 0.3435 - val_accuracy: 0.8581
# Epoch 52/180
# 127/127 [==============================] - 19s 152ms/step - loss: 0.3910 - accuracy: 0.8329 - val_loss: 0.4011 - val_accuracy: 0.8115

# %%
# Plot the transfer learning loss and val loss
plt.figure(figsize=(15,5))
plt.plot(history['loss'], label="Transfer Learning Loss", alpha=.3, color='#54aedb', linestyle='--')
plt.plot(history['val_loss'], label='Transfer Learning Validation Loss', alpha=.8, color='#54aedb')
plt.legend(loc='upper left')
plt.title('Loss')
plt.grid(alpha=.3)

# Plot the transfer learning accuracy and val accuracy
plt.figure(figsize=(15,5))
plt.plot(history['accuracy'], label='Transfer Learning Accuracy', alpha=.3, color='#54aedb', linestyle='--')
plt.plot(history['val_accuracy'], label='Transfer Learning Validation Accuracy', alpha=.8, color='#54aedb')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Predict labels for the entire test set
predictions = model.predict(data_test*255, verbose=0)

# %%
# Evaluate the model on the test set
test_accuracy = model.evaluate(preprocess_input(data_test*255),labels_test,verbose=0)[-1]
print('Test set accuracy %.4f' % test_accuracy)
# Out:
# Test set accuracy 0.8862

# %%
y = np.array(labels_test)

# %% [markdown]
# ## Confusion matrix

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y, axis=-1), np.argmax(predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(y, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y, axis=-1), np.argmax(predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, xticklabels=list(("healthy", "unhealthy")), yticklabels=list(("healthy", "unhealthy")), cmap='Blues', annot=True)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.8862
# Precision: 0.8949
# Recall: 0.8638
# F1: 0.875

# %%
# Save the best model
model.save('ConvNextBase_TL')
del model

# %% [markdown]
# # Fine Tuninig ConvNeXtBase

# %%
# Re-load the model after transfer learning
ft_model = tfk.models.load_model('ConvNextBase_TL')
ft_model.summary()
# Out:
# Model: "convnext_base"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  preprocessing (Sequential)  (None, 96, 96, 3)         0
#
#  convnext_base (Functional)  (None, 1024)              87566464
#
#  dropout (Dropout)           (None, 1024)              0
#
#  Output (Dense)              (None, 2)                 2050
#
# =================================================================
# Total params: 87568514 (334.05 MB)
# Trainable params: 2050 (8.01 KB)
# Non-trainable params: 87566464 (334.04 MB)
# _________________________________________________________________

# %%
# Set all ConvNeXtBase layers as trainable
ft_model.get_layer('convnext_base').trainable = True
for i, layer in enumerate(ft_model.get_layer('convnext_base').layers):
   print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 True
# 1 convnext_base_prestem_normalization True
# 2 convnext_base_stem True
# 3 convnext_base_stage_0_block_0_depthwise_conv True
# 4 convnext_base_stage_0_block_0_layernorm True
# 5 convnext_base_stage_0_block_0_pointwise_conv_1 True
# 6 convnext_base_stage_0_block_0_gelu True
# 7 convnext_base_stage_0_block_0_pointwise_conv_2 True
# 8 convnext_base_stage_0_block_0_layer_scale True
# 9 convnext_base_stage_0_block_0_identity True
# 10 tf.__operators__.add True
# 11 convnext_base_stage_0_block_1_depthwise_conv True
# 12 convnext_base_stage_0_block_1_layernorm True
# 13 convnext_base_stage_0_block_1_pointwise_conv_1 True
# 14 convnext_base_stage_0_block_1_gelu True
# 15 convnext_base_stage_0_block_1_pointwise_conv_2 True
# 16 convnext_base_stage_0_block_1_layer_scale True
# 17 convnext_base_stage_0_block_1_identity True
# 18 tf.__operators__.add_1 True
# 19 convnext_base_stage_0_block_2_depthwise_conv True
# 20 convnext_base_stage_0_block_2_layernorm True
# 21 convnext_base_stage_0_block_2_pointwise_conv_1 True
# 22 convnext_base_stage_0_block_2_gelu True
# 23 convnext_base_stage_0_block_2_pointwise_conv_2 True
# 24 convnext_base_stage_0_block_2_layer_scale True
# 25 convnext_base_stage_0_block_2_identity True
# 26 tf.__operators__.add_2 True
# 27 convnext_base_downsampling_block_0 True
# 28 convnext_base_stage_1_block_0_depthwise_conv True
# 29 convnext_base_stage_1_block_0_layernorm True
# 30 convnext_base_stage_1_block_0_pointwise_conv_1 True
# 31 convnext_base_stage_1_block_0_gelu True
# 32 convnext_base_stage_1_block_0_pointwise_conv_2 True
# 33 convnext_base_stage_1_block_0_layer_scale True
# 34 convnext_base_stage_1_block_0_identity True
# 35 tf.__operators__.add_3 True
# 36 convnext_base_stage_1_block_1_depthwise_conv True
# 37 convnext_base_stage_1_block_1_layernorm True
# 38 convnext_base_stage_1_block_1_pointwise_conv_1 True
# 39 convnext_base_stage_1_block_1_gelu True
# 40 convnext_base_stage_1_block_1_pointwise_conv_2 True
# 41 convnext_base_stage_1_block_1_layer_scale True
# 42 convnext_base_stage_1_block_1_identity True
# 43 tf.__operators__.add_4 True
# 44 convnext_base_stage_1_block_2_depthwise_conv True
# 45 convnext_base_stage_1_block_2_layernorm True
# 46 convnext_base_stage_1_block_2_pointwise_conv_1 True
# 47 convnext_base_stage_1_block_2_gelu True
# 48 convnext_base_stage_1_block_2_pointwise_conv_2 True
# 49 convnext_base_stage_1_block_2_layer_scale True
# 50 convnext_base_stage_1_block_2_identity True
# 51 tf.__operators__.add_5 True
# 52 convnext_base_downsampling_block_1 True
# 53 convnext_base_stage_2_block_0_depthwise_conv True
# 54 convnext_base_stage_2_block_0_layernorm True
# 55 convnext_base_stage_2_block_0_pointwise_conv_1 True
# 56 convnext_base_stage_2_block_0_gelu True
# 57 convnext_base_stage_2_block_0_pointwise_conv_2 True
# 58 convnext_base_stage_2_block_0_layer_scale True
# 59 convnext_base_stage_2_block_0_identity True
# 60 tf.__operators__.add_6 True
# 61 convnext_base_stage_2_block_1_depthwise_conv True
# 62 convnext_base_stage_2_block_1_layernorm True
# 63 convnext_base_stage_2_block_1_pointwise_conv_1 True
# 64 convnext_base_stage_2_block_1_gelu True
# 65 convnext_base_stage_2_block_1_pointwise_conv_2 True
# 66 convnext_base_stage_2_block_1_layer_scale True
# 67 convnext_base_stage_2_block_1_identity True
# 68 tf.__operators__.add_7 True
# 69 convnext_base_stage_2_block_2_depthwise_conv True
# 70 convnext_base_stage_2_block_2_layernorm True
# 71 convnext_base_stage_2_block_2_pointwise_conv_1 True
# 72 convnext_base_stage_2_block_2_gelu True
# 73 convnext_base_stage_2_block_2_pointwise_conv_2 True
# 74 convnext_base_stage_2_block_2_layer_scale True
# 75 convnext_base_stage_2_block_2_identity True
# 76 tf.__operators__.add_8 True
# 77 convnext_base_stage_2_block_3_depthwise_conv True
# 78 convnext_base_stage_2_block_3_layernorm True
# 79 convnext_base_stage_2_block_3_pointwise_conv_1 True
# 80 convnext_base_stage_2_block_3_gelu True
# 81 convnext_base_stage_2_block_3_pointwise_conv_2 True
# 82 convnext_base_stage_2_block_3_layer_scale True
# 83 convnext_base_stage_2_block_3_identity True
# 84 tf.__operators__.add_9 True
# 85 convnext_base_stage_2_block_4_depthwise_conv True
# 86 convnext_base_stage_2_block_4_layernorm True
# 87 convnext_base_stage_2_block_4_pointwise_conv_1 True
# 88 convnext_base_stage_2_block_4_gelu True
# 89 convnext_base_stage_2_block_4_pointwise_conv_2 True
# 90 convnext_base_stage_2_block_4_layer_scale True
# 91 convnext_base_stage_2_block_4_identity True
# 92 tf.__operators__.add_10 True
# 93 convnext_base_stage_2_block_5_depthwise_conv True
# 94 convnext_base_stage_2_block_5_layernorm True
# 95 convnext_base_stage_2_block_5_pointwise_conv_1 True
# 96 convnext_base_stage_2_block_5_gelu True
# 97 convnext_base_stage_2_block_5_pointwise_conv_2 True
# 98 convnext_base_stage_2_block_5_layer_scale True
# 99 convnext_base_stage_2_block_5_identity True
# 100 tf.__operators__.add_11 True
# 101 convnext_base_stage_2_block_6_depthwise_conv True
# 102 convnext_base_stage_2_block_6_layernorm True
# 103 convnext_base_stage_2_block_6_pointwise_conv_1 True
# 104 convnext_base_stage_2_block_6_gelu True
# 105 convnext_base_stage_2_block_6_pointwise_conv_2 True
# 106 convnext_base_stage_2_block_6_layer_scale True
# 107 convnext_base_stage_2_block_6_identity True
# 108 tf.__operators__.add_12 True
# 109 convnext_base_stage_2_block_7_depthwise_conv True
# 110 convnext_base_stage_2_block_7_layernorm True
# 111 convnext_base_stage_2_block_7_pointwise_conv_1 True
# 112 convnext_base_stage_2_block_7_gelu True
# 113 convnext_base_stage_2_block_7_pointwise_conv_2 True
# 114 convnext_base_stage_2_block_7_layer_scale True
# 115 convnext_base_stage_2_block_7_identity True
# 116 tf.__operators__.add_13 True
# 117 convnext_base_stage_2_block_8_depthwise_conv True
# 118 convnext_base_stage_2_block_8_layernorm True
# 119 convnext_base_stage_2_block_8_pointwise_conv_1 True
# 120 convnext_base_stage_2_block_8_gelu True
# 121 convnext_base_stage_2_block_8_pointwise_conv_2 True
# 122 convnext_base_stage_2_block_8_layer_scale True
# 123 convnext_base_stage_2_block_8_identity True
# 124 tf.__operators__.add_14 True
# 125 convnext_base_stage_2_block_9_depthwise_conv True
# 126 convnext_base_stage_2_block_9_layernorm True
# 127 convnext_base_stage_2_block_9_pointwise_conv_1 True
# 128 convnext_base_stage_2_block_9_gelu True
# 129 convnext_base_stage_2_block_9_pointwise_conv_2 True
# 130 convnext_base_stage_2_block_9_layer_scale True
# 131 convnext_base_stage_2_block_9_identity True
# 132 tf.__operators__.add_15 True
# 133 convnext_base_stage_2_block_10_depthwise_conv True
# 134 convnext_base_stage_2_block_10_layernorm True
# 135 convnext_base_stage_2_block_10_pointwise_conv_1 True
# 136 convnext_base_stage_2_block_10_gelu True
# 137 convnext_base_stage_2_block_10_pointwise_conv_2 True
# 138 convnext_base_stage_2_block_10_layer_scale True
# 139 convnext_base_stage_2_block_10_identity True
# 140 tf.__operators__.add_16 True
# 141 convnext_base_stage_2_block_11_depthwise_conv True
# 142 convnext_base_stage_2_block_11_layernorm True
# 143 convnext_base_stage_2_block_11_pointwise_conv_1 True
# 144 convnext_base_stage_2_block_11_gelu True
# 145 convnext_base_stage_2_block_11_pointwise_conv_2 True
# 146 convnext_base_stage_2_block_11_layer_scale True
# 147 convnext_base_stage_2_block_11_identity True
# 148 tf.__operators__.add_17 True
# 149 convnext_base_stage_2_block_12_depthwise_conv True
# 150 convnext_base_stage_2_block_12_layernorm True
# 151 convnext_base_stage_2_block_12_pointwise_conv_1 True
# 152 convnext_base_stage_2_block_12_gelu True
# 153 convnext_base_stage_2_block_12_pointwise_conv_2 True
# 154 convnext_base_stage_2_block_12_layer_scale True
# 155 convnext_base_stage_2_block_12_identity True
# 156 tf.__operators__.add_18 True
# 157 convnext_base_stage_2_block_13_depthwise_conv True
# 158 convnext_base_stage_2_block_13_layernorm True
# 159 convnext_base_stage_2_block_13_pointwise_conv_1 True
# 160 convnext_base_stage_2_block_13_gelu True
# 161 convnext_base_stage_2_block_13_pointwise_conv_2 True
# 162 convnext_base_stage_2_block_13_layer_scale True
# 163 convnext_base_stage_2_block_13_identity True
# 164 tf.__operators__.add_19 True
# 165 convnext_base_stage_2_block_14_depthwise_conv True
# 166 convnext_base_stage_2_block_14_layernorm True
# 167 convnext_base_stage_2_block_14_pointwise_conv_1 True
# 168 convnext_base_stage_2_block_14_gelu True
# 169 convnext_base_stage_2_block_14_pointwise_conv_2 True
# 170 convnext_base_stage_2_block_14_layer_scale True
# 171 convnext_base_stage_2_block_14_identity True
# 172 tf.__operators__.add_20 True
# 173 convnext_base_stage_2_block_15_depthwise_conv True
# 174 convnext_base_stage_2_block_15_layernorm True
# 175 convnext_base_stage_2_block_15_pointwise_conv_1 True
# 176 convnext_base_stage_2_block_15_gelu True
# 177 convnext_base_stage_2_block_15_pointwise_conv_2 True
# 178 convnext_base_stage_2_block_15_layer_scale True
# 179 convnext_base_stage_2_block_15_identity True
# 180 tf.__operators__.add_21 True
# 181 convnext_base_stage_2_block_16_depthwise_conv True
# 182 convnext_base_stage_2_block_16_layernorm True
# 183 convnext_base_stage_2_block_16_pointwise_conv_1 True
# 184 convnext_base_stage_2_block_16_gelu True
# 185 convnext_base_stage_2_block_16_pointwise_conv_2 True
# 186 convnext_base_stage_2_block_16_layer_scale True
# 187 convnext_base_stage_2_block_16_identity True
# 188 tf.__operators__.add_22 True
# 189 convnext_base_stage_2_block_17_depthwise_conv True
# 190 convnext_base_stage_2_block_17_layernorm True
# 191 convnext_base_stage_2_block_17_pointwise_conv_1 True
# 192 convnext_base_stage_2_block_17_gelu True
# 193 convnext_base_stage_2_block_17_pointwise_conv_2 True
# 194 convnext_base_stage_2_block_17_layer_scale True
# 195 convnext_base_stage_2_block_17_identity True
# 196 tf.__operators__.add_23 True
# 197 convnext_base_stage_2_block_18_depthwise_conv True
# 198 convnext_base_stage_2_block_18_layernorm True
# 199 convnext_base_stage_2_block_18_pointwise_conv_1 True
# 200 convnext_base_stage_2_block_18_gelu True
# 201 convnext_base_stage_2_block_18_pointwise_conv_2 True
# 202 convnext_base_stage_2_block_18_layer_scale True
# 203 convnext_base_stage_2_block_18_identity True
# 204 tf.__operators__.add_24 True
# 205 convnext_base_stage_2_block_19_depthwise_conv True
# 206 convnext_base_stage_2_block_19_layernorm True
# 207 convnext_base_stage_2_block_19_pointwise_conv_1 True
# 208 convnext_base_stage_2_block_19_gelu True
# 209 convnext_base_stage_2_block_19_pointwise_conv_2 True
# 210 convnext_base_stage_2_block_19_layer_scale True
# 211 convnext_base_stage_2_block_19_identity True
# 212 tf.__operators__.add_25 True
# 213 convnext_base_stage_2_block_20_depthwise_conv True
# 214 convnext_base_stage_2_block_20_layernorm True
# 215 convnext_base_stage_2_block_20_pointwise_conv_1 True
# 216 convnext_base_stage_2_block_20_gelu True
# 217 convnext_base_stage_2_block_20_pointwise_conv_2 True
# 218 convnext_base_stage_2_block_20_layer_scale True
# 219 convnext_base_stage_2_block_20_identity True
# 220 tf.__operators__.add_26 True
# 221 convnext_base_stage_2_block_21_depthwise_conv True
# 222 convnext_base_stage_2_block_21_layernorm True
# 223 convnext_base_stage_2_block_21_pointwise_conv_1 True
# 224 convnext_base_stage_2_block_21_gelu True
# 225 convnext_base_stage_2_block_21_pointwise_conv_2 True
# 226 convnext_base_stage_2_block_21_layer_scale True
# 227 convnext_base_stage_2_block_21_identity True
# 228 tf.__operators__.add_27 True
# 229 convnext_base_stage_2_block_22_depthwise_conv True
# 230 convnext_base_stage_2_block_22_layernorm True
# 231 convnext_base_stage_2_block_22_pointwise_conv_1 True
# 232 convnext_base_stage_2_block_22_gelu True
# 233 convnext_base_stage_2_block_22_pointwise_conv_2 True
# 234 convnext_base_stage_2_block_22_layer_scale True
# 235 convnext_base_stage_2_block_22_identity True
# 236 tf.__operators__.add_28 True
# 237 convnext_base_stage_2_block_23_depthwise_conv True
# 238 convnext_base_stage_2_block_23_layernorm True
# 239 convnext_base_stage_2_block_23_pointwise_conv_1 True
# 240 convnext_base_stage_2_block_23_gelu True
# 241 convnext_base_stage_2_block_23_pointwise_conv_2 True
# 242 convnext_base_stage_2_block_23_layer_scale True
# 243 convnext_base_stage_2_block_23_identity True
# 244 tf.__operators__.add_29 True
# 245 convnext_base_stage_2_block_24_depthwise_conv True
# 246 convnext_base_stage_2_block_24_layernorm True
# 247 convnext_base_stage_2_block_24_pointwise_conv_1 True
# 248 convnext_base_stage_2_block_24_gelu True
# 249 convnext_base_stage_2_block_24_pointwise_conv_2 True
# 250 convnext_base_stage_2_block_24_layer_scale True
# 251 convnext_base_stage_2_block_24_identity True
# 252 tf.__operators__.add_30 True
# 253 convnext_base_stage_2_block_25_depthwise_conv True
# 254 convnext_base_stage_2_block_25_layernorm True
# 255 convnext_base_stage_2_block_25_pointwise_conv_1 True
# 256 convnext_base_stage_2_block_25_gelu True
# 257 convnext_base_stage_2_block_25_pointwise_conv_2 True
# 258 convnext_base_stage_2_block_25_layer_scale True
# 259 convnext_base_stage_2_block_25_identity True
# 260 tf.__operators__.add_31 True
# 261 convnext_base_stage_2_block_26_depthwise_conv True
# 262 convnext_base_stage_2_block_26_layernorm True
# 263 convnext_base_stage_2_block_26_pointwise_conv_1 True
# 264 convnext_base_stage_2_block_26_gelu True
# 265 convnext_base_stage_2_block_26_pointwise_conv_2 True
# 266 convnext_base_stage_2_block_26_layer_scale True
# 267 convnext_base_stage_2_block_26_identity True
# 268 tf.__operators__.add_32 True
# 269 convnext_base_downsampling_block_2 True
# 270 convnext_base_stage_3_block_0_depthwise_conv True
# 271 convnext_base_stage_3_block_0_layernorm True
# 272 convnext_base_stage_3_block_0_pointwise_conv_1 True
# 273 convnext_base_stage_3_block_0_gelu True
# 274 convnext_base_stage_3_block_0_pointwise_conv_2 True
# 275 convnext_base_stage_3_block_0_layer_scale True
# 276 convnext_base_stage_3_block_0_identity True
# 277 tf.__operators__.add_33 True
# 278 convnext_base_stage_3_block_1_depthwise_conv True
# 279 convnext_base_stage_3_block_1_layernorm True
# 280 convnext_base_stage_3_block_1_pointwise_conv_1 True
# 281 convnext_base_stage_3_block_1_gelu True
# 282 convnext_base_stage_3_block_1_pointwise_conv_2 True
# 283 convnext_base_stage_3_block_1_layer_scale True
# 284 convnext_base_stage_3_block_1_identity True
# 285 tf.__operators__.add_34 True
# 286 convnext_base_stage_3_block_2_depthwise_conv True
# 287 convnext_base_stage_3_block_2_layernorm True
# 288 convnext_base_stage_3_block_2_pointwise_conv_1 True
# 289 convnext_base_stage_3_block_2_gelu True
# 290 convnext_base_stage_3_block_2_pointwise_conv_2 True
# 291 convnext_base_stage_3_block_2_layer_scale True
# 292 convnext_base_stage_3_block_2_identity True
# 293 tf.__operators__.add_35 True
# 294 global_average_pooling2d True
# 295 layer_normalization True

# %%
# Freeze first 180 layers
N = 180
for i, layer in enumerate(ft_model.get_layer('convnext_base').layers[:N]):
  layer.trainable=False
for i, layer in enumerate(ft_model.get_layer('convnext_base').layers):
   print(i, layer.name, layer.trainable)
ft_model.summary()
# Out:
# 0 input_1 False
# 1 convnext_base_prestem_normalization False
# 2 convnext_base_stem False
# 3 convnext_base_stage_0_block_0_depthwise_conv False
# 4 convnext_base_stage_0_block_0_layernorm False
# 5 convnext_base_stage_0_block_0_pointwise_conv_1 False
# 6 convnext_base_stage_0_block_0_gelu False
# 7 convnext_base_stage_0_block_0_pointwise_conv_2 False
# 8 convnext_base_stage_0_block_0_layer_scale False
# 9 convnext_base_stage_0_block_0_identity False
# 10 tf.__operators__.add False
# 11 convnext_base_stage_0_block_1_depthwise_conv False
# 12 convnext_base_stage_0_block_1_layernorm False
# 13 convnext_base_stage_0_block_1_pointwise_conv_1 False
# 14 convnext_base_stage_0_block_1_gelu False
# 15 convnext_base_stage_0_block_1_pointwise_conv_2 False
# 16 convnext_base_stage_0_block_1_layer_scale False
# 17 convnext_base_stage_0_block_1_identity False
# 18 tf.__operators__.add_1 False
# 19 convnext_base_stage_0_block_2_depthwise_conv False
# 20 convnext_base_stage_0_block_2_layernorm False
# 21 convnext_base_stage_0_block_2_pointwise_conv_1 False
# 22 convnext_base_stage_0_block_2_gelu False
# 23 convnext_base_stage_0_block_2_pointwise_conv_2 False
# 24 convnext_base_stage_0_block_2_layer_scale False
# 25 convnext_base_stage_0_block_2_identity False
# 26 tf.__operators__.add_2 False
# 27 convnext_base_downsampling_block_0 False
# 28 convnext_base_stage_1_block_0_depthwise_conv False
# 29 convnext_base_stage_1_block_0_layernorm False
# 30 convnext_base_stage_1_block_0_pointwise_conv_1 False
# 31 convnext_base_stage_1_block_0_gelu False
# 32 convnext_base_stage_1_block_0_pointwise_conv_2 False
# 33 convnext_base_stage_1_block_0_layer_scale False
# 34 convnext_base_stage_1_block_0_identity False
# 35 tf.__operators__.add_3 False
# 36 convnext_base_stage_1_block_1_depthwise_conv False
# 37 convnext_base_stage_1_block_1_layernorm False
# 38 convnext_base_stage_1_block_1_pointwise_conv_1 False
# 39 convnext_base_stage_1_block_1_gelu False
# 40 convnext_base_stage_1_block_1_pointwise_conv_2 False
# 41 convnext_base_stage_1_block_1_layer_scale False
# 42 convnext_base_stage_1_block_1_identity False
# 43 tf.__operators__.add_4 False
# 44 convnext_base_stage_1_block_2_depthwise_conv False
# 45 convnext_base_stage_1_block_2_layernorm False
# 46 convnext_base_stage_1_block_2_pointwise_conv_1 False
# 47 convnext_base_stage_1_block_2_gelu False
# 48 convnext_base_stage_1_block_2_pointwise_conv_2 False
# 49 convnext_base_stage_1_block_2_layer_scale False
# 50 convnext_base_stage_1_block_2_identity False
# 51 tf.__operators__.add_5 False
# 52 convnext_base_downsampling_block_1 False
# 53 convnext_base_stage_2_block_0_depthwise_conv False
# 54 convnext_base_stage_2_block_0_layernorm False
# 55 convnext_base_stage_2_block_0_pointwise_conv_1 False
# 56 convnext_base_stage_2_block_0_gelu False
# 57 convnext_base_stage_2_block_0_pointwise_conv_2 False
# 58 convnext_base_stage_2_block_0_layer_scale False
# 59 convnext_base_stage_2_block_0_identity False
# 60 tf.__operators__.add_6 False
# 61 convnext_base_stage_2_block_1_depthwise_conv False
# 62 convnext_base_stage_2_block_1_layernorm False
# 63 convnext_base_stage_2_block_1_pointwise_conv_1 False
# 64 convnext_base_stage_2_block_1_gelu False
# 65 convnext_base_stage_2_block_1_pointwise_conv_2 False
# 66 convnext_base_stage_2_block_1_layer_scale False
# 67 convnext_base_stage_2_block_1_identity False
# 68 tf.__operators__.add_7 False
# 69 convnext_base_stage_2_block_2_depthwise_conv False
# 70 convnext_base_stage_2_block_2_layernorm False
# 71 convnext_base_stage_2_block_2_pointwise_conv_1 False
# 72 convnext_base_stage_2_block_2_gelu False
# 73 convnext_base_stage_2_block_2_pointwise_conv_2 False
# 74 convnext_base_stage_2_block_2_layer_scale False
# 75 convnext_base_stage_2_block_2_identity False
# 76 tf.__operators__.add_8 False
# 77 convnext_base_stage_2_block_3_depthwise_conv False
# 78 convnext_base_stage_2_block_3_layernorm False
# 79 convnext_base_stage_2_block_3_pointwise_conv_1 False
# 80 convnext_base_stage_2_block_3_gelu False
# 81 convnext_base_stage_2_block_3_pointwise_conv_2 False
# 82 convnext_base_stage_2_block_3_layer_scale False
# 83 convnext_base_stage_2_block_3_identity False
# 84 tf.__operators__.add_9 False
# 85 convnext_base_stage_2_block_4_depthwise_conv False
# 86 convnext_base_stage_2_block_4_layernorm False
# 87 convnext_base_stage_2_block_4_pointwise_conv_1 False
# 88 convnext_base_stage_2_block_4_gelu False
# 89 convnext_base_stage_2_block_4_pointwise_conv_2 False
# 90 convnext_base_stage_2_block_4_layer_scale False
# 91 convnext_base_stage_2_block_4_identity False
# 92 tf.__operators__.add_10 False
# 93 convnext_base_stage_2_block_5_depthwise_conv False
# 94 convnext_base_stage_2_block_5_layernorm False
# 95 convnext_base_stage_2_block_5_pointwise_conv_1 False
# 96 convnext_base_stage_2_block_5_gelu False
# 97 convnext_base_stage_2_block_5_pointwise_conv_2 False
# 98 convnext_base_stage_2_block_5_layer_scale False
# 99 convnext_base_stage_2_block_5_identity False
# 100 tf.__operators__.add_11 False
# 101 convnext_base_stage_2_block_6_depthwise_conv False
# 102 convnext_base_stage_2_block_6_layernorm False
# 103 convnext_base_stage_2_block_6_pointwise_conv_1 False
# 104 convnext_base_stage_2_block_6_gelu False
# 105 convnext_base_stage_2_block_6_pointwise_conv_2 False
# 106 convnext_base_stage_2_block_6_layer_scale False
# 107 convnext_base_stage_2_block_6_identity False
# 108 tf.__operators__.add_12 False
# 109 convnext_base_stage_2_block_7_depthwise_conv False
# 110 convnext_base_stage_2_block_7_layernorm False
# 111 convnext_base_stage_2_block_7_pointwise_conv_1 False
# 112 convnext_base_stage_2_block_7_gelu False
# 113 convnext_base_stage_2_block_7_pointwise_conv_2 False
# 114 convnext_base_stage_2_block_7_layer_scale False
# 115 convnext_base_stage_2_block_7_identity False
# 116 tf.__operators__.add_13 False
# 117 convnext_base_stage_2_block_8_depthwise_conv False
# 118 convnext_base_stage_2_block_8_layernorm False
# 119 convnext_base_stage_2_block_8_pointwise_conv_1 False
# 120 convnext_base_stage_2_block_8_gelu False
# 121 convnext_base_stage_2_block_8_pointwise_conv_2 False
# 122 convnext_base_stage_2_block_8_layer_scale False
# 123 convnext_base_stage_2_block_8_identity False
# 124 tf.__operators__.add_14 False
# 125 convnext_base_stage_2_block_9_depthwise_conv False
# 126 convnext_base_stage_2_block_9_layernorm False
# 127 convnext_base_stage_2_block_9_pointwise_conv_1 False
# 128 convnext_base_stage_2_block_9_gelu False
# 129 convnext_base_stage_2_block_9_pointwise_conv_2 False
# 130 convnext_base_stage_2_block_9_layer_scale False
# 131 convnext_base_stage_2_block_9_identity False
# 132 tf.__operators__.add_15 False
# 133 convnext_base_stage_2_block_10_depthwise_conv False
# 134 convnext_base_stage_2_block_10_layernorm False
# 135 convnext_base_stage_2_block_10_pointwise_conv_1 False
# 136 convnext_base_stage_2_block_10_gelu False
# 137 convnext_base_stage_2_block_10_pointwise_conv_2 False
# 138 convnext_base_stage_2_block_10_layer_scale False
# 139 convnext_base_stage_2_block_10_identity False
# 140 tf.__operators__.add_16 False
# 141 convnext_base_stage_2_block_11_depthwise_conv False
# 142 convnext_base_stage_2_block_11_layernorm False
# 143 convnext_base_stage_2_block_11_pointwise_conv_1 False
# 144 convnext_base_stage_2_block_11_gelu False
# 145 convnext_base_stage_2_block_11_pointwise_conv_2 False
# 146 convnext_base_stage_2_block_11_layer_scale False
# 147 convnext_base_stage_2_block_11_identity False
# 148 tf.__operators__.add_17 False
# 149 convnext_base_stage_2_block_12_depthwise_conv False
# 150 convnext_base_stage_2_block_12_layernorm False
# 151 convnext_base_stage_2_block_12_pointwise_conv_1 False
# 152 convnext_base_stage_2_block_12_gelu False
# 153 convnext_base_stage_2_block_12_pointwise_conv_2 False
# 154 convnext_base_stage_2_block_12_layer_scale False
# 155 convnext_base_stage_2_block_12_identity False
# 156 tf.__operators__.add_18 False
# 157 convnext_base_stage_2_block_13_depthwise_conv False
# 158 convnext_base_stage_2_block_13_layernorm False
# 159 convnext_base_stage_2_block_13_pointwise_conv_1 False
# 160 convnext_base_stage_2_block_13_gelu False
# 161 convnext_base_stage_2_block_13_pointwise_conv_2 False
# 162 convnext_base_stage_2_block_13_layer_scale False
# 163 convnext_base_stage_2_block_13_identity False
# 164 tf.__operators__.add_19 False
# 165 convnext_base_stage_2_block_14_depthwise_conv False
# 166 convnext_base_stage_2_block_14_layernorm False
# 167 convnext_base_stage_2_block_14_pointwise_conv_1 False
# 168 convnext_base_stage_2_block_14_gelu False
# 169 convnext_base_stage_2_block_14_pointwise_conv_2 False
# 170 convnext_base_stage_2_block_14_layer_scale False
# 171 convnext_base_stage_2_block_14_identity False
# 172 tf.__operators__.add_20 False
# 173 convnext_base_stage_2_block_15_depthwise_conv False
# 174 convnext_base_stage_2_block_15_layernorm False
# 175 convnext_base_stage_2_block_15_pointwise_conv_1 False
# 176 convnext_base_stage_2_block_15_gelu False
# 177 convnext_base_stage_2_block_15_pointwise_conv_2 False
# 178 convnext_base_stage_2_block_15_layer_scale False
# 179 convnext_base_stage_2_block_15_identity False
# 180 tf.__operators__.add_21 True
# 181 convnext_base_stage_2_block_16_depthwise_conv True
# 182 convnext_base_stage_2_block_16_layernorm True
# 183 convnext_base_stage_2_block_16_pointwise_conv_1 True
# 184 convnext_base_stage_2_block_16_gelu True
# 185 convnext_base_stage_2_block_16_pointwise_conv_2 True
# 186 convnext_base_stage_2_block_16_layer_scale True
# 187 convnext_base_stage_2_block_16_identity True
# 188 tf.__operators__.add_22 True
# 189 convnext_base_stage_2_block_17_depthwise_conv True
# 190 convnext_base_stage_2_block_17_layernorm True
# 191 convnext_base_stage_2_block_17_pointwise_conv_1 True
# 192 convnext_base_stage_2_block_17_gelu True
# 193 convnext_base_stage_2_block_17_pointwise_conv_2 True
# 194 convnext_base_stage_2_block_17_layer_scale True
# 195 convnext_base_stage_2_block_17_identity True
# 196 tf.__operators__.add_23 True
# 197 convnext_base_stage_2_block_18_depthwise_conv True
# 198 convnext_base_stage_2_block_18_layernorm True
# 199 convnext_base_stage_2_block_18_pointwise_conv_1 True
# 200 convnext_base_stage_2_block_18_gelu True
# 201 convnext_base_stage_2_block_18_pointwise_conv_2 True
# 202 convnext_base_stage_2_block_18_layer_scale True
# 203 convnext_base_stage_2_block_18_identity True
# 204 tf.__operators__.add_24 True
# 205 convnext_base_stage_2_block_19_depthwise_conv True
# 206 convnext_base_stage_2_block_19_layernorm True
# 207 convnext_base_stage_2_block_19_pointwise_conv_1 True
# 208 convnext_base_stage_2_block_19_gelu True
# 209 convnext_base_stage_2_block_19_pointwise_conv_2 True
# 210 convnext_base_stage_2_block_19_layer_scale True
# 211 convnext_base_stage_2_block_19_identity True
# 212 tf.__operators__.add_25 True
# 213 convnext_base_stage_2_block_20_depthwise_conv True
# 214 convnext_base_stage_2_block_20_layernorm True
# 215 convnext_base_stage_2_block_20_pointwise_conv_1 True
# 216 convnext_base_stage_2_block_20_gelu True
# 217 convnext_base_stage_2_block_20_pointwise_conv_2 True
# 218 convnext_base_stage_2_block_20_layer_scale True
# 219 convnext_base_stage_2_block_20_identity True
# 220 tf.__operators__.add_26 True
# 221 convnext_base_stage_2_block_21_depthwise_conv True
# 222 convnext_base_stage_2_block_21_layernorm True
# 223 convnext_base_stage_2_block_21_pointwise_conv_1 True
# 224 convnext_base_stage_2_block_21_gelu True
# 225 convnext_base_stage_2_block_21_pointwise_conv_2 True
# 226 convnext_base_stage_2_block_21_layer_scale True
# 227 convnext_base_stage_2_block_21_identity True
# 228 tf.__operators__.add_27 True
# 229 convnext_base_stage_2_block_22_depthwise_conv True
# 230 convnext_base_stage_2_block_22_layernorm True
# 231 convnext_base_stage_2_block_22_pointwise_conv_1 True
# 232 convnext_base_stage_2_block_22_gelu True
# 233 convnext_base_stage_2_block_22_pointwise_conv_2 True
# 234 convnext_base_stage_2_block_22_layer_scale True
# 235 convnext_base_stage_2_block_22_identity True
# 236 tf.__operators__.add_28 True
# 237 convnext_base_stage_2_block_23_depthwise_conv True
# 238 convnext_base_stage_2_block_23_layernorm True
# 239 convnext_base_stage_2_block_23_pointwise_conv_1 True
# 240 convnext_base_stage_2_block_23_gelu True
# 241 convnext_base_stage_2_block_23_pointwise_conv_2 True
# 242 convnext_base_stage_2_block_23_layer_scale True
# 243 convnext_base_stage_2_block_23_identity True
# 244 tf.__operators__.add_29 True
# 245 convnext_base_stage_2_block_24_depthwise_conv True
# 246 convnext_base_stage_2_block_24_layernorm True
# 247 convnext_base_stage_2_block_24_pointwise_conv_1 True
# 248 convnext_base_stage_2_block_24_gelu True
# 249 convnext_base_stage_2_block_24_pointwise_conv_2 True
# 250 convnext_base_stage_2_block_24_layer_scale True
# 251 convnext_base_stage_2_block_24_identity True
# 252 tf.__operators__.add_30 True
# 253 convnext_base_stage_2_block_25_depthwise_conv True
# 254 convnext_base_stage_2_block_25_layernorm True
# 255 convnext_base_stage_2_block_25_pointwise_conv_1 True
# 256 convnext_base_stage_2_block_25_gelu True
# 257 convnext_base_stage_2_block_25_pointwise_conv_2 True
# 258 convnext_base_stage_2_block_25_layer_scale True
# 259 convnext_base_stage_2_block_25_identity True
# 260 tf.__operators__.add_31 True
# 261 convnext_base_stage_2_block_26_depthwise_conv True
# 262 convnext_base_stage_2_block_26_layernorm True
# 263 convnext_base_stage_2_block_26_pointwise_conv_1 True
# 264 convnext_base_stage_2_block_26_gelu True
# 265 convnext_base_stage_2_block_26_pointwise_conv_2 True
# 266 convnext_base_stage_2_block_26_layer_scale True
# 267 convnext_base_stage_2_block_26_identity True
# 268 tf.__operators__.add_32 True
# 269 convnext_base_downsampling_block_2 True
# 270 convnext_base_stage_3_block_0_depthwise_conv True
# 271 convnext_base_stage_3_block_0_layernorm True
# 272 convnext_base_stage_3_block_0_pointwise_conv_1 True
# 273 convnext_base_stage_3_block_0_gelu True
# 274 convnext_base_stage_3_block_0_pointwise_conv_2 True
# 275 convnext_base_stage_3_block_0_layer_scale True
# 276 convnext_base_stage_3_block_0_identity True
# 277 tf.__operators__.add_33 True
# 278 convnext_base_stage_3_block_1_depthwise_conv True
# 279 convnext_base_stage_3_block_1_layernorm True
# 280 convnext_base_stage_3_block_1_pointwise_conv_1 True
# 281 convnext_base_stage_3_block_1_gelu True
# 282 convnext_base_stage_3_block_1_pointwise_conv_2 True
# 283 convnext_base_stage_3_block_1_layer_scale True
# 284 convnext_base_stage_3_block_1_identity True
# 285 tf.__operators__.add_34 True
# 286 convnext_base_stage_3_block_2_depthwise_conv True
# 287 convnext_base_stage_3_block_2_layernorm True
# 288 convnext_base_stage_3_block_2_pointwise_conv_1 True
# 289 convnext_base_stage_3_block_2_gelu True
# 290 convnext_base_stage_3_block_2_pointwise_conv_2 True
# 291 convnext_base_stage_3_block_2_layer_scale True
# 292 convnext_base_stage_3_block_2_identity True
# 293 tf.__operators__.add_35 True
# 294 global_average_pooling2d True
# 295 layer_normalization True
# Model: "convnext_base"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  preprocessing (Sequential)  (None, 96, 96, 3)         0
#
#  convnext_base (Functional)  (None, 1024)              87566464
#
#  dropout (Dropout)           (None, 1024)              0
#
#  Output (Dense)              (None, 2)                 2050
#
# =================================================================
# Total params: 87568514 (334.05 MB)
# Trainable params: 50842626 (193.95 MB)
# Non-trainable params: 36725888 (140.10 MB)
# _________________________________________________________________

# %%
# Compile the model
ft_model.compile(loss=tfk.losses.BinaryCrossentropy(), optimizer=tfk.optimizers.Adam(1e-5), metrics='accuracy')

# %%
# Fine-tune the model
ft_history = ft_model.fit(
    x = preprocess_input(data_train*255), # We need to apply the preprocessing thought for the network
    y = labels_train,
    batch_size = 32,
    epochs = 180,
    validation_data = (preprocess_input(data_val*255), labels_val), # We need to apply the preprocessing thought for the network
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True)]
).history
# Out:
# Epoch 1/180
# 127/127 [==============================] - 85s 360ms/step - loss: 0.4203 - accuracy: 0.8443 - val_loss: 0.3615 - val_accuracy: 0.8514
# Epoch 2/180
# 127/127 [==============================] - 29s 230ms/step - loss: 0.3642 - accuracy: 0.8576 - val_loss: 0.3315 - val_accuracy: 0.8603
# Epoch 3/180
# 127/127 [==============================] - 29s 229ms/step - loss: 0.3287 - accuracy: 0.8692 - val_loss: 0.3201 - val_accuracy: 0.8692
# Epoch 4/180
# 127/127 [==============================] - 28s 222ms/step - loss: 0.3011 - accuracy: 0.8840 - val_loss: 0.2946 - val_accuracy: 0.8758
# Epoch 5/180
# 127/127 [==============================] - 28s 223ms/step - loss: 0.2778 - accuracy: 0.8922 - val_loss: 0.2883 - val_accuracy: 0.8869
# Epoch 6/180
# 127/127 [==============================] - 29s 229ms/step - loss: 0.2664 - accuracy: 0.8944 - val_loss: 0.2803 - val_accuracy: 0.8758
# Epoch 7/180
# 127/127 [==============================] - 28s 222ms/step - loss: 0.2435 - accuracy: 0.9072 - val_loss: 0.2824 - val_accuracy: 0.8714
# Epoch 8/180
# 127/127 [==============================] - 28s 223ms/step - loss: 0.2281 - accuracy: 0.9136 - val_loss: 0.2557 - val_accuracy: 0.8869
# Epoch 9/180
# 127/127 [==============================] - 28s 222ms/step - loss: 0.2211 - accuracy: 0.9205 - val_loss: 0.2487 - val_accuracy: 0.8980
# Epoch 10/180
# 127/127 [==============================] - 29s 229ms/step - loss: 0.2057 - accuracy: 0.9232 - val_loss: 0.2410 - val_accuracy: 0.9091
# Epoch 11/180
# 127/127 [==============================] - 28s 222ms/step - loss: 0.1918 - accuracy: 0.9282 - val_loss: 0.2426 - val_accuracy: 0.8958
# Epoch 12/180
# 127/127 [==============================] - 29s 229ms/step - loss: 0.1705 - accuracy: 0.9393 - val_loss: 0.2401 - val_accuracy: 0.9069
# Epoch 13/180
# 127/127 [==============================] - 28s 222ms/step - loss: 0.1674 - accuracy: 0.9356 - val_loss: 0.2422 - val_accuracy: 0.9069
# Epoch 14/180
# 127/127 [==============================] - 29s 229ms/step - loss: 0.1569 - accuracy: 0.9455 - val_loss: 0.2159 - val_accuracy: 0.9202
# Epoch 15/180
# 127/127 [==============================] - 28s 220ms/step - loss: 0.1545 - accuracy: 0.9435 - val_loss: 0.2253 - val_accuracy: 0.9135
# Epoch 16/180
# 127/127 [==============================] - 29s 228ms/step - loss: 0.1324 - accuracy: 0.9521 - val_loss: 0.2197 - val_accuracy: 0.9047
# Epoch 17/180
# 127/127 [==============================] - 28s 222ms/step - loss: 0.1293 - accuracy: 0.9595 - val_loss: 0.2338 - val_accuracy: 0.9091
# Epoch 18/180
# 127/127 [==============================] - 29s 229ms/step - loss: 0.1175 - accuracy: 0.9576 - val_loss: 0.2773 - val_accuracy: 0.8936
# Epoch 19/180
# 127/127 [==============================] - 29s 230ms/step - loss: 0.1087 - accuracy: 0.9617 - val_loss: 0.2337 - val_accuracy: 0.9180

# %%
# Plot the fine tuning loss and val loss
plt.figure(figsize=(15,5))
plt.plot(ft_history['loss'], label="Transfer Learning Loss", alpha=.3, color='#54aedb', linestyle='--')
plt.plot(ft_history['val_loss'], label='Transfer Learning Validation Loss', alpha=.8, color='#54aedb')
plt.legend(loc='upper left')
plt.title('Loss')
plt.grid(alpha=.3)

# Plot the fine tuning accuracy and val accuracy
plt.figure(figsize=(15,5))
plt.plot(ft_history['accuracy'], label='Transfer Learning Accuracy', alpha=.3, color='#54aedb', linestyle='--')
plt.plot(ft_history['val_accuracy'], label='Transfer Learning Validation Accuracy', alpha=.8, color='#54aedb')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Plot the transfer learning validation loss and fine tuning validation loss
plt.figure(figsize=(15,5))
plt.plot(history['val_loss'], label="Transfer Learning Validation Loss", alpha=.3, color='#54aedb', linestyle='--')
plt.plot(ft_history['val_loss'], label='Fine Tuning Validation Loss', alpha=.8, color='#54aedb')
plt.legend(loc='upper left')
plt.title('Loss')
plt.grid(alpha=.3)

# Plot the transfer learning validation accuracy and fine tuning validation accuracy
plt.figure(figsize=(15,5))
plt.plot(history['val_accuracy'], label='Transfer Learning Validation Accuracy', alpha=.3, color='#54aedb', linestyle='--')
plt.plot(ft_history['val_accuracy'], label='Fine Tuning Validation Accuracy', alpha=.8, color='#54aedb')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Predict labels for the entire test set
predictions = ft_model.predict(data_test*255, verbose=0)

# %%
# Evaluate the model on the test set
test_accuracy = ft_model.evaluate(preprocess_input(data_test*255),labels_test,verbose=0)[-1]
print('Test set accuracy %.4f' % test_accuracy)
# Out:
# Test set accuracy 0.9281

# %%
y = np.array(labels_test)

# %% [markdown]
# ## Confusion matrix

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y, axis=-1), np.argmax(predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(y, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y, axis=-1), np.argmax(predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, xticklabels=list(("healthy", "unhealthy")), yticklabels=list(("healthy", "unhealthy")), cmap='Blues', annot=True)
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.9281
# Precision: 0.9316
# Recall: 0.9158
# F1: 0.9225

# %%
# Save the best model
ft_model.save('ConvNextBase_TL+FT___9142')
del ft_model
